# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Nnamdi Osia </b> <br>
# Cyber Info Assurance Engineer

# %% [markdown]
# <i> I am interested in data science because I believe it is an emerging need in many companies. Individuals and companies alike are now
# able to tell stories using data as insight and I believe this to be very valuable to any company looking to grow their business and make sound decisions. </i>

# %% [markdown]
# ### My code in Cell 5 will add "1+1"

# %%
1+1
# Out:
# 2

# %% [markdown]
# __[This is an example of a linked website! - IBM CLOUD](https://dataplatform.cloud.ibm.com/)__
# <hr> <br>
# Here is a horizontal line <br>
# <hr> <br>
# Here is a grocery list, numbered <br>
# <ol>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ol> <br>
# Here is the same grocery list, bulleted  <br>
# <ul>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ul>
